# %% [markdown]
# Manipulação de strings

# %%
nome = 'Fábio'
letra = nome[2]
print(letra)
print(len(nome))
# Out:
# b
# 5

# %%
nome = 'Curso de Python'
instrutor = 'Fábio'
print(nome + ' com ' + instrutor)
# Out:
# Curso de Python com Fábio

# %%
frase = 'Vamos aprender Python hoje'
palavras = frase.split()
print(palavras)
# Out:
# ['Vamos', 'aprender', 'Python', 'hoje']

# %%
print(palavras[1])
# Out:
# aprender

# %%
for letra in frase:
  print(letra)
# Out:
# V
# a
# m
# o
# s
#
# a
# p
# r
# e
# n
# d
# e
# r
#
# P
# y
# t
# h
# o
# n
#
# h
# o
# j
# e

# %%
print(frase[0:5])
# Out:
# Vamos

# %%
print(frase[6:15])
# Out:
# aprender

# %%
print(frase[7:19])
# Out:
# prender Pyth

# %%
print(frase[-3:])
# Out:
# oje

# %%
email = input('Digite seu endereço de e-mail: ')
arroba = email.find('@')
print(arroba)
# Out:
# Digite seu endereço de e-mail: fabio@boson.com.br
# 5

# %%
usuario = email[0:arroba]
dominio = email[arroba+1:]
print(usuario)
print(dominio)
# Out:
# fabio
# boson.com.br

# %%
produtos = 'carbonato de sódio e óxido de zinco'
print('sódio' in produtos)
print('magnésio' in produtos)
# Out:
# True
# False

# %%
print('magnésio' not in produtos)
# Out:
# True

# %% [markdown]
# Quando o método find não encontrar o valor ele retorna -1

# %%
item = 'hipoclorito'
pos = item.find('clor')
print(pos)
pos = item.find('flu')
print(pos)
# Out:
# 4
# -1

# %%
objeto_celeste = 'galáxia esPiral M31'
print(objeto_celeste.upper())
# Out:
# GALÁXIA ESPIRAL M31

# %%
print(objeto_celeste.lower())
# Out:
# galáxia espiral m31

# %% [markdown]
# Primeira letra da frase toda em maiúsculo.

# %%
print(objeto_celeste.capitalize())
# Out:
# Galáxia espiral m31

# %%
print(objeto_celeste.title())
# Out:
# Galáxia Espiral M31

# %%
suplemento = 'cloreto de magnésio'
n_suplemento = suplemento.replace('magnésio', 'zinco')
print(suplemento)
print(n_suplemento)
# Out:
# cloreto de magnésio
# cloreto de zinco

# %%
frase = '    Ômega 3 é bom para a saúde    '
print(frase)
print(frase.lstrip())
print(frase.rstrip())
print(frase.strip())
# Out:
#     Ômega 3 é bom para a saúde
# Ômega 3 é bom para a saúde
#     Ômega 3 é bom para a saúde
# Ômega 3 é bom para a saúde

# %%
fruta = 'Abacate'
print(fruta)
print(fruta.rjust(20))
# Out:
# Abacate
#              Abacate

# %%
print(fruta.center(20))
# Out:
#       Abacate

# %%
print(fruta.ljust(20))
# Out:
# Abacate

# %%
print(fruta.ljust(20, '-'))
# Out:
# Abacate-------------

# %%
print(fruta.center(20, '-'))
# Out:
# ------Abacate-------

# %%
p = 'Bóson Treinamentos'
print(p.startswith('Bó'))
# Out:
# True

# %%
print(p.startswith('b'))
# Out:
# False

# %%
print(p.endswith('s'))
# Out:
# True

# %%
print(p.endswith('o'))
# Out:
# False

# %% [markdown]
# Docstrings

# %%
texto = """
Docstring é uma espécie de documentação
que podemos inserir dentro de um módulo, função
ou classe no Python, entre outros locais.
     Respeita deslocamento do texto e é    multilinhas
"""
print(texto)
# Out:
# Docstring é uma espécie de documentação
# que podemos inserir dentro de um módulo, função
# ou classe no Python, entre outros locais.
#      Respeita deslocamento do texto e é    multilinhas
