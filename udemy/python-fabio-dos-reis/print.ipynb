# %% [markdown]
# # Função print()
#
# A função print é uma função interna do Python. Não precisa importar nenhuma biblioteca para poder usar.
#
# Iniciando com Hello World!

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# Sintaxe significa qual a forma correta de escrever algo.

# %%
# Sintaxe:
# print(objetos, argumentos)

# %% [markdown]
# Imprimindo o que está em uma variável.

# %%
mensagem = 'Função print()'
print(mensagem)
# Out:
# Função print()

# %% [markdown]
# ## O que é um literal de string?
#
# Um literal de string é uma sequência de caracteres de texto que aparece diretamente no seu código fonte. Pense nele como um valor fixo do tipo texto que você fornece ao programa.
#
# Por exemplo, a frase "Olá, mundo!" dentro de aspas duplas é um literal de string.
#
# Os literais de string são usados para representar texto dentro do programa, como mensagens exibidas na tela, dados lidos de um arquivo ou qualquer outra informação textual que precise ser armazenada ou manipulada.
#
# Para definir uma literal de string, a maioria das linguagens de programação usa aspas simples ('') ou aspas duplas (""). Às vezes, ambas as opções funcionam da mesma forma, mas pode haver casos específicos onde uma é preferível que a outra. É sempre melhor consultar a documentação da linguagem de programação que você está usando para saber a sintaxe correta.
#
# Imprimindo uma literal de string direto.

# %%
print('Aula de Python')
# Out:
# Aula de Python

# %% [markdown]
# Podemos usar argumentos posicionais.

# %%
nome = 'Fábio dos Reis'
canal = 'Bóson Treinamentos'
print('Bóson Treinamentos -', nome)
print(canal, '-', nome)
# Out:
# Bóson Treinamentos - Fábio dos Reis
# Bóson Treinamentos - Fábio dos Reis

# %% [markdown]
# Podemos concatenar strings.

# %%
nome = input('Digite seu nome: ')
print('Olá ' + nome + '! Bem-vindo ao curso de Python!')

# %%
nome = input('Digite seu nome: ')
msg = 'Olá ' + nome + '! Bem-vindo ao curso de Python!'
print(msg)
# Out:
# Digite seu nome: Gustavo
# Olá Gustavo! Bem-vindo ao curso de Python!

# %% [markdown]
# A função print por padrão inclui uma quebra de linha ao final
#
# Mas podemos desabilitar isso. Basta colocar end = ' ' ao final

# %%
print('primeira mensagem com quebra de linha.')
print('segunda mensagem sem quebra de linha.', end='')
print(' terceira mensagem.')
# Out:
# primeira mensagem com quebra de linha.
# segunda mensagem sem quebra de linha. terceira mensagem.

# %% [markdown]
# Podemos utilizar um método especial para strings chamado string.format()
#
# Utilizado para inserir valores em uma strig em qualquer posição desejada.

# %%
nome = 'Maria'
idade = 30
msg_formatada = 'O nome dela é {0} e ela tem {1} anos.'.format(nome, idade)
print(msg_formatada)
# Out:
# O nome dela é Maria e ela tem 30 anos.

# %%
print('O nome dela é {0} e ela tem {1} anos.'.format(nome, idade))
# Out:
# O nome dela é Maria e ela tem 30 anos.

# %% [markdown]
# ## O que é uma f-string?
#
# Formated string literal
#
# É uma maneira mais fácil e mais legível de formatar strings para exibir uma literal de string na saída.

# %%
nome = 'Fábio'
peso = 73.50
msg = f'Olá, meu nome é {nome} e eu peso {peso} quilos.'
print(msg)
# Out:
# Olá, meu nome é Fábio e eu peso 73.5 quilos.

# %%
print(f'Olá, meu nome é {nome} e eu peso {peso} quilos.')
# Out:
# Olá, meu nome é Fábio e eu peso 73.5 quilos.

# %% [markdown]
# Podemos executar expressões direto dentro da f-string.

# %%
a = 10
b = 5
res = f'A soma de {a} com {b} é igual a {a + b}'
print(res)
# Out:
# A soma de 10 com 5 é igual a 15

# %% [markdown]
# Podemos, também, formatar números de ponto flutuante usando f-string.

# %%
valor = 125.579637
print(f'O valor é {valor}')
# Out:
# O valor é 125.579637

# %% [markdown]
# Depois da palavra **valor** coloco : e  escrevo .2 para indicar que são 2 casas decimais e f para indicar que é um número de ponto flutuante.

# %%
print(f'O valor é {valor:.2f}')
# Out:
# O valor é 125.58

# %% [markdown]
# Também podemos usar caracteres de escape.

# %%
print(f'O valor é \'{valor:.2f}\'')
# Out:
# O valor é '125.58'

# %% [markdown]
# Usando caracter de tabulação (TAB)

# %%
nome = 'João'
idade = 32
print(f'Nome: {nome}\tIdade: {idade}')
# Out:
# Nome: João	Idade: 32

# %% [markdown]
# ## Slices de uma string (fatias, intervalos)
#
# Podemos imprimir um intervalo de uma cadeia de caracteres (string)
#
# Imprimindo slices de uma string

# %%
texto = 'Frase para testar'
print(texto[0])
print(texto[0:3])
print(texto[6:10])
print(texto[:10])
print(texto[6:])
# Out:
# F
# Fra
# para
# Frase para
# para testar
